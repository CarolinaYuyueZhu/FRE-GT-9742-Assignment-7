# %%
import sys, os
repo_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if repo_root not in sys.path:
    sys.path.insert(0, repo_root)
print("Added to sys.path:", repo_root)
from fixedincomelib import *
print("Fixed Income Library is loaded.")
# Out:
# Added to sys.path: /Users/yuyuezhu/Desktop/FRE-GT-9743-Assignment-7
# Fixed Income Library is loaded.

# %%
# utilities
def display_res(input_dict : Dict[SimpleMetrics, float]):
    display({k.to_string() : v for k, v in input_dict.items()})

# %% [markdown]
# Please follow the instructions in 'european_options.py' in analytics folder.
#
# Then verify with the following code.

# %% [markdown]
# ### Test European Option Analytics

# %%
### log normal vol
forward = 0.04
strike = 0.042
ln_sigma = 0.20
tte = 0.5
call_or_put = 'put'
res_ln_pricing = qfEuropeanOptionLogNormal(forward, strike, tte, ln_sigma, call_or_put, True)
display_res(res_ln_pricing)
# Out:
# {'pv': np.float64(0.0034471895385265877),
#  'delta': np.float64(-0.608068301568095),
#  'gamma': np.float64(67.92009043331392),
#  'vega': np.float64(0.01086721446933023),
#  'strike_risk': np.float64(0.6611886095535807),
#  'theta': np.float64(-0.0021734428938660457)}

# %%
### b&r test
key = SimpleMetrics.PV
base_pv = res_ln_pricing[key]

epsilon = 1e-6
bump_vec = [0.] * 4
for i in range(len(bump_vec)):
    bump_vec[i] += epsilon    
    bumped_pv = qfEuropeanOptionLogNormal(
        forward + bump_vec[0], 
        strike + bump_vec[1], 
        tte - bump_vec[2], 
        ln_sigma + bump_vec[3], 
        call_or_put)
    display((bumped_pv[key] - base_pv) / epsilon)
    bump_vec[i] -= epsilon
# Out:
# np.float64(-0.6080343412546985)
# np.float64(0.6612194113492231)
# np.float64(-0.0021734438519771526)
# np.float64(0.010867217570265097)

# %%
### implied lognormal vol
forward = 0.04
strike = 0.042
pv = res_ln_pricing[SimpleMetrics.PV]
tte = 0.5
res_ln_iv = qfEuropeanOptionImpliedLogNormalVol(pv, forward, strike, tte, call_or_put, True)
display_res(res_ln_iv)
# Out:
# {'implied_log_normal_vol': np.float64(0.2000004189689407),
#  'd_ln_vol_d_forward': np.float64(55.954340778786865),
#  'd_ln_vol_d_strike': np.float64(-60.84247653659664),
#  'd_ln_vol_d_tte': np.float64(-0.20000041896894064)}

# %%
### b&r test
key = SimpleMetrics.IMPLIED_LOG_NORMAL_VOL
base_imp_ln_vol = res_ln_iv[key]

epsilon = 1e-6
bump_vec = [0.] * 3
for i in range(len(bump_vec)):
    bump_vec[i] += epsilon    
    bumped_ln_vol = qfEuropeanOptionImpliedLogNormalVol(
        pv, 
        forward + bump_vec[0], 
        strike + bump_vec[1], 
        tte + bump_vec[2], 
        call_or_put)
    display((bumped_ln_vol[key] - base_imp_ln_vol) / epsilon)
    bump_vec[i] -= epsilon
# Out:
# np.float64(55.94325139188228)
# np.float64(-60.84618949936394)
# np.float64(-0.2000001189939038)

# %%
### normal vol from lognormal vol
forward = 0.04
strike = 0.042
shift = 0.04
ln_vol = res_ln_iv[SimpleMetrics.IMPLIED_LOG_NORMAL_VOL]
tte = 0.5
res_n_vol = qfEuropeanOptionNormalVolFromLogNormalVol(forward, strike, tte, ln_vol, shift, True)
display_res(res_n_vol)
# Out:
# {'implied_normal_vol': np.float64(0.01618572189241275),
#  'd_n_vol_d_ln_vol': np.float64(0.08079364793832612),
#  'd_n_vol_d_forward': np.float64(0.10074437075552134),
#  'd_n_vol_d_strike': np.float64(0.09909965833792955),
#  'd_n_vol_d_tte': np.float64(-2.6958454718440522e-05)}

# %%
### b&r test
key = SimpleMetrics.IMPLIED_NORMAL_VOL
base_n_vol = res_n_vol[key]

epsilon = 1e-6
bump_vec = [0.] * 4
for i in range(len(bump_vec)):
    bump_vec[i] += epsilon    
    bumped_n_vol = qfEuropeanOptionNormalVolFromLogNormalVol(
        forward + bump_vec[0], 
        strike + bump_vec[1], 
        tte + bump_vec[2], 
        ln_vol + bump_vec[3],
        shift)
    display((bumped_n_vol[key] - base_n_vol) / epsilon)
    bump_vec[i] -= epsilon
# Out:
# np.float64(0.10074282869726447)
# np.float64(0.09910076599964346)
# np.float64(-2.6960822463450995e-05)
# np.float64(0.0807936350009919)

# %%
### normal vol
forward = 0.04
strike = 0.042
shift = 0.04
n_sigma = res_n_vol[SimpleMetrics.IMPLIED_NORMAL_VOL]
tte = 0.5
res_nv_pricing = qfEuropeanOptionNormal(forward, strike, tte, n_sigma, call_or_put, True)
display_res(res_nv_pricing)
# Out:
# {'pv': np.float64(0.005635445460400287),
#  'delta': np.float64(-0.5693612868156247),
#  'gamma': np.float64(34.329064804444265),
#  'vega': np.float64(0.27782034787567483),
#  'strike_risk': np.float64(0.5693612868156247),
#  'theta': np.float64(-0.0044967228867690365)}

# %%
### b&r test
key = SimpleMetrics.PV
base_pv = res_nv_pricing[key]

epsilon = 1e-6
bump_vec = [0.] * 4
for i in range(len(bump_vec)):
    bump_vec[i] += epsilon    
    bumped_pv = qfEuropeanOptionNormal(
        forward + bump_vec[0], 
        strike + bump_vec[1], 
        tte - bump_vec[2], 
        n_sigma + bump_vec[3], 
        call_or_put)
    display((bumped_pv[key] - base_pv) / epsilon)
    bump_vec[i] -= epsilon
# Out:
# np.float64(-0.5693441221957599)
# np.float64(0.5693784512613917)
# np.float64(-0.004496725065222806)
# np.float64(0.27782060993755686)

# %%
### implied normal vol
forward = 0.04
strike = 0.042
pv = res_nv_pricing[SimpleMetrics.PV]
tte = 0.5
res_nv_imp = qfEuropeanOptionImpliedNormalVol(pv, forward, strike, tte, call_or_put, True)
display_res(res_nv_imp)
# Out:
# {'implied_normal_vol': np.float64(0.016185721966829925),
#  'd_n_vol_d_forward': np.float64(2.0493865578010393),
#  'd_n_vol_d_strike': np.float64(-2.0493865578010393),
#  'd_n_vol_d_tte': np.float64(-0.016185721966829922)}

# %%
### b&r test
key = SimpleMetrics.IMPLIED_NORMAL_VOL
base_imp_n_vol = res_nv_imp[key]

epsilon = 1e-6
bump_vec = [0.] * 3
for i in range(len(bump_vec)):
    bump_vec[i] += epsilon    
    bumped_n_vol = qfEuropeanOptionImpliedNormalVol(
        pv, 
        forward + bump_vec[0], 
        strike + bump_vec[1], 
        tte + bump_vec[2], 
        call_or_put)
    display((bumped_n_vol[key] - base_imp_n_vol) / epsilon)
    bump_vec[i] -= epsilon
# Out:
# np.float64(2.049289107405178)
# np.float64(-2.04948317678727)
# np.float64(-0.01618569769185063)

# %%
### lognormal vol from normal vol
forward = 0.04
strike = 0.042
shift = 0.04
n_vol = res_nv_imp[SimpleMetrics.IMPLIED_NORMAL_VOL]
tte = 0.5
res_ln_iv_round_trip = qfEuropeanOptionLogNormalVolFromNormalVol( \
    forward, strike, tte, n_vol, shift, True)
display_res(res_ln_iv_round_trip)
# Out:
# {'implied_log_normal_vol': np.float64(0.2000004246274847),
#  'd_ln_vol_d_n_vol': np.float64(12.377210646345377),
#  'd_ln_vol_d_forward': np.float64(-1.2469344067292631),
#  'd_ln_vol_d_strike': np.float64(-1.2265773094266237),
#  'd_ln_vol_d_tte': np.float64(0.0003336656191488818)}

# %%
### b&r test
key = SimpleMetrics.IMPLIED_LOG_NORMAL_VOL
base_ln_vol = res_ln_iv_round_trip[key]

epsilon = 1e-6
bump_vec = [0.] * 4
for i in range(len(bump_vec)):
    bump_vec[i] += epsilon    
    bumped_ln_vol = qfEuropeanOptionLogNormalVolFromNormalVol(
        forward + bump_vec[0], 
        strike + bump_vec[1], 
        tte + bump_vec[2], 
        n_vol + bump_vec[3],
        shift)
    display((bumped_ln_vol[key] - base_ln_vol) / epsilon)
    bump_vec[i] -= epsilon
# Out:
# np.float64(-1.246933567955466)
# np.float64(-1.2265576767034325)
# np.float64(0.00033364686014003553)
# np.float64(12.377211372760488)
